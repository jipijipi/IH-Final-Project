# %%
import pandas as pd
from typing import List, Set
import re

# %%
# Prepare the input data
df = pd.read_csv('data/paintings_with_filenames.csv') 
df
# Out:
#                                             item  \
# 0         http://www.wikidata.org/entity/Q607761
# 1         http://www.wikidata.org/entity/Q609572
# 2         http://www.wikidata.org/entity/Q607598
# 3         http://www.wikidata.org/entity/Q734082
# 4         http://www.wikidata.org/entity/Q472037
# ...                                          ...
# 121662  http://www.wikidata.org/entity/Q98966261
# 121663  http://www.wikidata.org/entity/Q98977855
# 121664  http://www.wikidata.org/entity/Q99025930
# 121665  http://www.wikidata.org/entity/Q98970362
# 121666  http://www.wikidata.org/entity/Q98969203
#
#                                                     title  \
# 0                                The Death of the Picador
# 1                                           Manaò tupapaú
# 2                               Virgin of the Councillors
# 3                               Regatta at Sainte-Adresse
# 4                                         By the Seashore
# ...                                                   ...
# 121662                              Musical Entertainment
# 121663  Césarine de Houdetot, Baronne de Barante, read...
# 121664                                     The Broken Jug
# 121665       Dr Philippe Pinel (1745-1826) and his family
# 121666      Her Majesty Queen Elizabeth, The Queen Mother
#
#                                  author_wikidata                 author_name  \
# 0           http://www.wikidata.org/entity/Q5432              Francisco Goya
# 1          http://www.wikidata.org/entity/Q37693                Paul Gauguin
# 2         http://www.wikidata.org/entity/Q723863                Lluís Dalmau
# 3            http://www.wikidata.org/entity/Q296                Claude Monet
# 4          http://www.wikidata.org/entity/Q39931       Pierre-Auguste Renoir
# ...                                          ...                         ...
# 121662  http://www.wikidata.org/entity/Q18613400       Jakob Emanuel Gaisser
# 121663  http://www.wikidata.org/entity/Q51077254           Louise Bouteiller
# 121664  http://www.wikidata.org/entity/Q97477673        Jenny Berger-Désoras
# 121665   http://www.wikidata.org/entity/Q3291501  Marie-Anne-Julie Forestier
# 121666   http://www.wikidata.org/entity/Q7329264               Richard Stone
#
#                creation_date origin_country           display_country  \
# 0       1793-01-01T00:00:00Z            NaN                       NaN
# 1       1892-01-01T00:00:00Z            NaN  United States of America
# 2       1445-01-01T00:00:00Z            NaN                     Spain
# 3       1867-01-01T00:00:00Z            NaN  United States of America
# 4       1883-01-01T00:00:00Z            NaN  United States of America
# ...                      ...            ...                       ...
# 121662  1899-01-01T00:00:00Z            NaN                       NaN
# 121663  1818-01-01T00:00:00Z         France                    France
# 121664  1847-01-01T00:00:00Z            NaN                       NaN
# 121665  1807-01-01T00:00:00Z            NaN                       NaN
# 121666  1986-01-01T00:00:00Z            NaN                       NaN
#
#                          display_location             type           school  \
# 0                                     NaN        genre art      Romanticism
# 1                  Buffalo AKG Art Museum        genre art    Impressionism
# 2       Museu Nacional d'Art de Catalunya    religious art  Gothic painting
# 3              Metropolitan Museum of Art       marine art    Impressionism
# 4              Metropolitan Museum of Art         portrait    Impressionism
# ...                                   ...              ...              ...
# 121662                                NaN        genre art              NaN
# 121663                 Château de Barante         portrait              NaN
# 121664                                NaN        genre art              NaN
# 121665                                NaN  family portrait              NaN
# 121666                                NaN         portrait              NaN
#
#        time_period  wiki_url  \
# 0              NaN       NaN
# 1              NaN       NaN
# 2              NaN       NaN
# 3              NaN       NaN
# 4              NaN       NaN
# ...            ...       ...
# 121662         NaN       NaN
# 121663         NaN       NaN
# 121664         NaN       NaN
# 121665         NaN       NaN
# 121666         NaN       NaN
#
#                                                 image_url  \
# 0       https://commons.wikimedia.org/wiki/Special:Fil...
# 1       https://commons.wikimedia.org/wiki/Special:Fil...
# 2       https://commons.wikimedia.org/wiki/Special:Fil...
# 3       https://commons.wikimedia.org/wiki/Special:Fil...
# 4       https://commons.wikimedia.org/wiki/Special:Fil...
# ...                                                   ...
# 121662  https://commons.wikimedia.org/wiki/Special:Fil...
# 121663  https://commons.wikimedia.org/wiki/Special:Fil...
# 121664  https://commons.wikimedia.org/wiki/Special:Fil...
# 121665  https://commons.wikimedia.org/wiki/Special:Fil...
# 121666  https://commons.wikimedia.org/wiki/Special:Fil...
#
#                                                   depicts  \
# 0       picador, stadium, spear, bullfighting, man, ho...
# 1       gaze, lying, intergluteal cleft, sole, barefoo...
# 2       Madonna and Child, Eulalia of Barcelona, Joan ...
# 3       parasol, sailboat, Sainte-Adresse, church, mar...
# 4         portrait, Saint Peter Port, coast, chair, woman
# ...                                                   ...
# 121662                                                NaN
# 121663  Saint François d‘Assise, Césarine d'Houdetot, ...
# 121664                                                NaN
# 121665  Scipion Pinel, Philippe Pinel, physician, chil...
# 121666                  Queen Elizabeth, The Queen Mother
#
#                                             wikipedia_url  \
# 0                                                     NaN
# 1       https://en.wikipedia.org/wiki/Spirit_of_the_De...
# 2       https://en.wikipedia.org/wiki/Virgin_of_the_Co...
# 3       https://en.wikipedia.org/wiki/Regatta_at_Saint...
# 4           https://en.wikipedia.org/wiki/By_the_Seashore
# ...                                                   ...
# 121662                                                NaN
# 121663                                                NaN
# 121664                                                NaN
# 121665                                                NaN
# 121666                                                NaN
#
#                                              article_text  \
# 0                                                     NaN
# 1       Spirit of the Dead Watching (Manao tupapau) is...
# 2       The Virgin of the Councillors is a panel paint...
# 3       The Regatta at Sainte-Adresse is an oil-on-can...
# 4       By the Seashore is a painting by Pierre-August...
# ...                                                   ...
# 121662                                                NaN
# 121663                                                NaN
# 121664                                                NaN
# 121665                                                NaN
# 121666                                                NaN
#
#                                               title_clean  \
# 0                                the death of the picador
# 1                                           manaò tupapaú
# 2                               virgin of the councillors
# 3                                regatta at sainteadresse
# 4                                         by the seashore
# ...                                                   ...
# 121662                              musical entertainment
# 121663  césarine de houdetot baronne de barante readin...
# 121664                                     the broken jug
# 121665          dr philippe pinel 17451826 and his family
# 121666       her majesty queen elizabeth the queen mother
#
#                                                  wga_url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3        https://www.wga.hu/html/m/monet/01/early16.html
# 4       https://www.wga.hu/html/r/renoir/3/3renoi20.html
# ...                                                  ...
# 121662                                               NaN
# 121663                                               NaN
# 121664                                               NaN
# 121665                                               NaN
# 121666                                               NaN
#
#                                           wga_description  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       In the summer of 1867, Monet painted a number ...
# 4       This canvas was painted in the artist's studio...
# ...                                                   ...
# 121662                                                NaN
# 121663                                                NaN
# 121664                                                NaN
# 121665                                                NaN
# 121666                                                NaN
#
#                                                  filename
# 0                               La_muerte_del_picador.jpg
# 1       Paul_Gauguin_-_Manaò_tupapaú_(Spirit_of_the_De...
# 2                  Dalmau_Mare_de_Deu_dels_Consellers.jpg
# 3       Claude_Monet,_1867,_Regatta_at_Sainte-Adresse,...
# 4       Pierre-Auguste_Renoir_-_Femme_assise_au_bord_d...
# ...                                                   ...
# 121662  Jakob_Emanuel_Gaisser_-_Musical_Entertainment.jpg
# 121663  Portrait_of_Cesarine_de_Houdetot_by_Louise_Bou...
# 121664         The_Broken_Jug_by_Jenny_Berger-Desoras.jpg
# 121665  Philippe_Pinel_and_his_family_by_Julie_Foresti...
# 121666      Queen_Elizabeth_the_Queen_Mother_portrait.jpg
#
# [121667 rows x 20 columns]

# %%
def extract_relevant_sections(text):
   
    if not isinstance(text, str):
        return None

    # Define regular expression patterns to match each section
    intro_pattern = r'^(.*?)(?=\n==)'
    description_pattern = r'== Description ==\n(.*?)(?=\n==|\Z)'
    interpretation_pattern = r'== Interpretations ==\n(.*?)(?=\n==|\Z)'

    # Search for each section
    intro = re.search(intro_pattern, text, re.DOTALL)
    description = re.search(description_pattern, text, re.DOTALL)
    interpretation = re.search(interpretation_pattern, text, re.DOTALL)

    # Extract the sections, if found
    result = ""
    if intro:
        result += intro.group(1).strip() + "\n\n"
    if description:
        result += "== Description ==\n" + description.group(1).strip() + "\n\n"
    if interpretation:
        result += "== Subject ==\n" + interpretation.group(1).strip()

    return result.strip()

# %%
df['wiki_description'] = df['article_text'].apply(extract_relevant_sections)

# Convert columns to strings and replace NaN with empty string
df['full_description'] = df[['title', 'depicts', 'wga_description', 'wiki_description']].astype(str).apply(lambda x: ' '.join(filter(None, x)), axis=1)

df.head()
# Out:
#                                      item                      title  \
# 0  http://www.wikidata.org/entity/Q607761   The Death of the Picador
# 1  http://www.wikidata.org/entity/Q609572              Manaò tupapaú
# 2  http://www.wikidata.org/entity/Q607598  Virgin of the Councillors
# 3  http://www.wikidata.org/entity/Q734082  Regatta at Sainte-Adresse
# 4  http://www.wikidata.org/entity/Q472037            By the Seashore
#
#                           author_wikidata            author_name  \
# 0    http://www.wikidata.org/entity/Q5432         Francisco Goya
# 1   http://www.wikidata.org/entity/Q37693           Paul Gauguin
# 2  http://www.wikidata.org/entity/Q723863           Lluís Dalmau
# 3     http://www.wikidata.org/entity/Q296           Claude Monet
# 4   http://www.wikidata.org/entity/Q39931  Pierre-Auguste Renoir
#
#           creation_date origin_country           display_country  \
# 0  1793-01-01T00:00:00Z            NaN                       NaN
# 1  1892-01-01T00:00:00Z            NaN  United States of America
# 2  1445-01-01T00:00:00Z            NaN                     Spain
# 3  1867-01-01T00:00:00Z            NaN  United States of America
# 4  1883-01-01T00:00:00Z            NaN  United States of America
#
#                     display_location           type           school  ...  \
# 0                                NaN      genre art      Romanticism  ...
# 1             Buffalo AKG Art Museum      genre art    Impressionism  ...
# 2  Museu Nacional d'Art de Catalunya  religious art  Gothic painting  ...
# 3         Metropolitan Museum of Art     marine art    Impressionism  ...
# 4         Metropolitan Museum of Art       portrait    Impressionism  ...
#
#                                            image_url  \
# 0  https://commons.wikimedia.org/wiki/Special:Fil...
# 1  https://commons.wikimedia.org/wiki/Special:Fil...
# 2  https://commons.wikimedia.org/wiki/Special:Fil...
# 3  https://commons.wikimedia.org/wiki/Special:Fil...
# 4  https://commons.wikimedia.org/wiki/Special:Fil...
#
#                                              depicts  \
# 0  picador, stadium, spear, bullfighting, man, ho...
# 1  gaze, lying, intergluteal cleft, sole, barefoo...
# 2  Madonna and Child, Eulalia of Barcelona, Joan ...
# 3  parasol, sailboat, Sainte-Adresse, church, mar...
# 4    portrait, Saint Peter Port, coast, chair, woman
#
#                                        wikipedia_url  \
# 0                                                NaN
# 1  https://en.wikipedia.org/wiki/Spirit_of_the_De...
# 2  https://en.wikipedia.org/wiki/Virgin_of_the_Co...
# 3  https://en.wikipedia.org/wiki/Regatta_at_Saint...
# 4      https://en.wikipedia.org/wiki/By_the_Seashore
#
#                                         article_text  \
# 0                                                NaN
# 1  Spirit of the Dead Watching (Manao tupapau) is...
# 2  The Virgin of the Councillors is a panel paint...
# 3  The Regatta at Sainte-Adresse is an oil-on-can...
# 4  By the Seashore is a painting by Pierre-August...
#
#                  title_clean  \
# 0   the death of the picador
# 1              manaò tupapaú
# 2  virgin of the councillors
# 3   regatta at sainteadresse
# 4            by the seashore
#
#                                             wga_url  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3   https://www.wga.hu/html/m/monet/01/early16.html
# 4  https://www.wga.hu/html/r/renoir/3/3renoi20.html
#
#                                      wga_description  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  In the summer of 1867, Monet painted a number ...
# 4  This canvas was painted in the artist's studio...
#
#                                             filename  \
# 0                          La_muerte_del_picador.jpg
# 1  Paul_Gauguin_-_Manaò_tupapaú_(Spirit_of_the_De...
# 2             Dalmau_Mare_de_Deu_dels_Consellers.jpg
# 3  Claude_Monet,_1867,_Regatta_at_Sainte-Adresse,...
# 4  Pierre-Auguste_Renoir_-_Femme_assise_au_bord_d...
#
#                                     wiki_description  \
# 0                                               None
# 1  Spirit of the Dead Watching (Manao tupapau) is...
# 2  The Virgin of the Councillors is a panel paint...
# 3  The Regatta at Sainte-Adresse is an oil-on-can...
# 4  By the Seashore is a painting by Pierre-August...
#
#                                     full_description
# 0  The Death of the Picador picador, stadium, spe...
# 1  Manaò tupapaú gaze, lying, intergluteal cleft,...
# 2  Virgin of the Councillors Madonna and Child, E...
# 3  Regatta at Sainte-Adresse parasol, sailboat, S...
# 4  By the Seashore portrait, Saint Peter Port, co...
#
# [5 rows x 22 columns]

# %%
def create_food_keywords() -> Set[str]:

    return {
        # Meals
        'breakfast', 'lunch', 'dinner', 'feast', 'banquet', 'brunch', 'snack', 'supper', 'tea', 'buffet', 'picnic', 'potluck', 'appetizer', 'dessert', 'main course',

        # Common foods
        'bread', 'fruit', 'meat', 'fish', 'cheese', 'wine', 'vegetables', 'salad', 'pasta', 'soup', 'stew', 'rice', 'cereal', 'nuts', 'seeds', 'juice', 'milk', 'honey', 'eggs', 'butter', 'yogurt', 'coffee', 'cake', 'pie', 'ice cream', 'chocolate', 'sugar', 'spices', 'herbs', 'olive oil', 'vinegar', 'salt', 'pepper',

        # Categories
        'food', 'meal', 'dish', 'cuisine', 'ingredient', 'beverage', 'desserts', 'appetizers',

        # Common verbs
        'eating', 'dining', 'cooking', 'baking', 'frying', 'grilling', 'roasting', 'boiling', 'steaming', 'toasting', 'preparing', 'serving', 'tasting', 'slicing', 'chopping', 'whisking', 'seasoning', 'marinating', 'garnishing'

    }


def check_food_mentions(df: pd.DataFrame,
                        description_column: str) -> pd.DataFrame:

    # Convert descriptions to lowercase for case-insensitive matching
    descriptions_lower = df[description_column].str.lower()

    # Combine default and custom keywords
    food_keywords = create_food_keywords()

    # Create regex pattern for efficient matching
    pattern = '|'.join(r'\b' + word + r'\b' for word in food_keywords)

    # Add columns to DataFrame
    df['contains_food'] = descriptions_lower.str.contains(pattern, regex=True)
    df['food_words'] = descriptions_lower.apply(
        lambda x: [word for word in food_keywords if f' {word} ' in f' {x} ']
    )
    df['food_word_count'] = df['food_words'].str.len()

    return df


""" # Example usage
if __name__ == "__main__":
    # Sample data
    data = {
        'title': ['Still Life with Fruit', 'Portrait of a Lady', 'The Last Supper'],
        'description': [
            'A beautiful arrangement of fresh fruits and bread on a table.',
            'A woman in a blue dress standing by a window.',
            'Jesus and disciples sharing their final meal together.'
        ]
    }
    df = pd.DataFrame(data)


    # Process the descriptions
    result = check_food_mentions(df, 'description') """

# %%
result = check_food_mentions(df, 'full_description')

# %%
result
