# %% [markdown]
# # Food in Art

# %%
import pandas as pd
import os
import time
import concurrent.futures
from typing import List, Dict
import requests
from ratelimit import limits, sleep_and_retry

# %%
# Initialize global session for connection pooling
session = requests.Session()
session.headers.update({
    'User-Agent': 'ArtDataBot/1.0 (jipijipijipi@gmail.com) Python/requests',
    'Accept': 'application/json'
})

@sleep_and_retry
@limits(calls=5, period=1)  # Limit to 5 calls per second
def run_sparql_query(query: str, endpoint_url: str) -> Dict:
    """Execute SPARQL query with rate limiting"""
    response = session.get(
        endpoint_url,
        params={'query': query, 'format': 'json'},
        timeout=30
    )
    response.raise_for_status()
    return response.json()

def process_batch(batch_qids: List[str], endpoint_url: str, query_template: str, src_column_name: str, max_retries: int = 5) -> pd.DataFrame:
    """Process a single batch of QIDs with a customizable SPARQL query template."""
    qid_list_str = ' '.join(f'wd:{qid}' for qid in batch_qids)
    # Insert the QID list and src_column_name into the query template
    batch_query = query_template.format(qid_list=qid_list_str, src_column_name=src_column_name)
    
    for retry in range(max_retries):
        try:
            results = run_sparql_query(batch_query, endpoint_url)
            bindings = results['results']['bindings']
            
            if not bindings:
                return pd.DataFrame()

            # Dynamically construct data extraction based on available fields
            data = []
            for b in bindings:
                row = {key: b.get(key, {}).get('value') for key in b}
                data.append(row)
            
            return pd.DataFrame(data)
            
        except Exception as e:
            if retry == max_retries - 1:
                print(f"Max retries exceeded: {e}")
                return pd.DataFrame()
            time.sleep(2 ** retry)  # Exponential backoff
    
    return pd.DataFrame()

def chunk_list(lst: List, chunk_size: int) -> List[List]:
    """Split a list into chunks of specified size"""
    return [lst[i:i + chunk_size] for i in range(0, len(lst), chunk_size)]

def get_supplement_from_wikidata(name, src_path, src_column_name, query_template: str):
    # Configuration
    endpoint_url = "https://query.wikidata.org/sparql"
    batch_size = 50
    max_workers = 3  # Adjust based on your needs and API limits
    checkpoint_frequency = 10  # Save checkpoint every N batches

    if os.path.exists(f'data/wikidata_{name}.csv'):
        print("Final file already exists. Skipping data retrieval.")
        return

    # Create checkpoint directory if it doesn't exist
    os.makedirs('data/checkpoints', exist_ok=True)

    # Load checkpoint if exists
    checkpoint_file = f'data/checkpoints/{name}_checkpoint.csv'
    batch_index_file = f'data/checkpoints/{name}_batch_index_checkpoint.txt'
    
    if os.path.exists(checkpoint_file) and os.path.exists(batch_index_file):
        detailed_data = pd.read_csv(checkpoint_file)
        with open(batch_index_file, 'r') as f:
            start_batch = int(f.read())
        print(f"Resuming from batch {start_batch}")
    else:
        detailed_data = pd.DataFrame()
        start_batch = 0

    # Read and prepare author data
    basic_data = pd.read_csv(src_path)
    results = basic_data[[src_column_name]].drop_duplicates().reset_index(drop=True)
    results = results.dropna(subset=[src_column_name])  # Drop rows where 'author_wikidata' is NaN
    # Drop values that do not start with 'http://www.wikidata.org/entity'
    results = results[results[src_column_name].str.startswith('http://www.wikidata.org/entity')]
    # Convert item URIs to Q-IDs and create batches
    src_qids = [uri.split('/')[-1] for uri in results[src_column_name].tolist()]
    
    batches = chunk_list(src_qids, batch_size)

    print(f"Processing {len(batches)} batches with {len(src_qids)} records...")

    # Process batches with ThreadPoolExecutor
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {
            executor.submit(process_batch, batch, endpoint_url, query_template, src_column_name): batch_idx 
            for batch_idx, batch in enumerate(batches[start_batch:], start=start_batch)
        }
        
        completed_batches = 0
        for future in concurrent.futures.as_completed(futures):
            batch_idx = futures[future]
            try:
                batch_df = future.result()
                if not batch_df.empty:
                    detailed_data = pd.concat([detailed_data, batch_df], ignore_index=True)
                
                completed_batches += 1
                print(f"Completed batch {batch_idx + 1}/{len(batches)} "
                      f"({(batch_idx + 1)/len(batches)*100:.1f}%)")

                # Save checkpoint periodically
                if completed_batches % checkpoint_frequency == 0:
                    detailed_data.to_csv(checkpoint_file, index=False)
                    with open(batch_index_file, 'w') as f:
                        f.write(str(batch_idx + 1))
                    print(f"Checkpoint saved at batch {batch_idx + 1}")

            except Exception as e:
                print(f"Error processing batch {batch_idx}: {e}")

    # Final processing
    print("Processing complete. Preparing final dataset...")
    detailed_data.drop_duplicates(inplace=True)
    final_data = pd.merge(results, detailed_data, on=src_column_name, how='left')
    
    # Save final results
    final_data.to_csv(f'data/wikidata_{name}.csv', index=False)
    print(f"Data saved to wikidata_{name}.csv")

    # Clean up checkpoints
    if os.path.exists(checkpoint_file):
        os.remove(checkpoint_file)
    if os.path.exists(batch_index_file):
        os.remove(batch_index_file)


author_query_template = """
SELECT DISTINCT ?{src_column_name} ?author_name ?country ?country_label ?gender ?gender_label 
       # ?date_of_birth ?place_of_birth ?place_of_birth_label 
       # ?place_of_birth_country ?place_of_birth_country_label 
WHERE {{
    VALUES ?{src_column_name} {{ {qid_list} }}
    
    # Author-specific information here
    OPTIONAL {{
        # ?{src_column_name} rdfs:label ?author_name.
        FILTER(LANG(?author_name) = "en")
    }}
    OPTIONAL {{
        # ?{src_column_name} wdt:P27 ?country.
        # ?country rdfs:label ?country_label.
        FILTER(LANG(?country_label) = "en")
    }}
    OPTIONAL {{
        # ?{src_column_name} wdt:P21 ?gender.
        # ?gender rdfs:label ?gender_label.
        FILTER(LANG(?gender_label) = "en")
    }}
    OPTIONAL {{
        # ?{src_column_name} wdt:P569 ?date_of_birth.
    }}
    OPTIONAL {{
        # ?{src_column_name} wdt:P19 ?place_of_birth.
        # ?place_of_birth rdfs:label ?place_of_birth_label.
        FILTER(LANG(?place_of_birth_label) = "en")
        OPTIONAL {{
            # ?place_of_birth wdt:P17 ?place_of_birth_country.
            # ?place_of_birth_country rdfs:label ?place_of_birth_country_label.
            FILTER(LANG(?place_of_birth_country_label) = "en")
        }}
    }}
}}
"""
paintings_query_template = """
    SELECT ?item ?creation_date ?origin_country ?display_country ?type ?school ?time_period ?image_url (GROUP_CONCAT(?depicts_label; separator=", ") AS ?depicts) WHERE {{
    VALUES ?item {{ {qid_list} }}
    
    OPTIONAL {{ ?item wdt:P571 ?creation_date. }}
    
    # Origin country of the item or the author
    OPTIONAL {{
        # ?item wdt:P495 ?origin_country_wd.
        # ?origin_country_wd rdfs:label ?origin_country.
        FILTER(LANG(?origin_country) = "en")
    }}
    OPTIONAL {{
        # ?item wdt:P50 ?author.
        # ?author wdt:P27 ?author_country_wd.
        # ?author_country_wd rdfs:label ?author_country.
        FILTER(LANG(?author_country) = "en")
    }}
    BIND(COALESCE(?origin_country, ?author_country) AS ?origin_country)
    
    # Display country
    OPTIONAL {{
        # ?item wdt:P276 ?display_location_wd.
        OPTIONAL {{
            # ?display_location_wd wdt:P17 ?display_country_wd.
            # ?display_country_wd rdfs:label ?display_country.
            FILTER(LANG(?display_country) = "en")
        }}
    }}
    
    # Type
    OPTIONAL {{
        # ?item wdt:P136 ?type_wd.
        # ?type_wd rdfs:label ?type.
        FILTER(LANG(?type) = "en")
    }}
    
    # School or tradition
    OPTIONAL {{
        # ?item wdt:P135 ?school_wd.
        # ?school_wd rdfs:label ?school.
        FILTER(LANG(?school) = "en")
    }}
    
    # Time period
    OPTIONAL {{
        # ?item wdt:P2348 ?time_period_wd.
        # ?time_period_wd rdfs:label ?time_period.
        FILTER(LANG(?time_period) = "en")
    }}
    
    # Image URL
    OPTIONAL {{
        # ?item wdt:P18 ?image_url.
    }}
    
    # Depicts
    OPTIONAL {{
        # ?item wdt:P180 ?depicts_wd.
        # ?depicts_wd rdfs:label ?depicts_label.
        FILTER(LANG(?depicts_label) = "en")
    }}
    }}
    GROUP BY ?item ?creation_date ?origin_country ?display_country ?type ?school ?time_period ?image_url
"""
      
get_supplement_from_wikidata('painters', 'data/wikidata_paintings_ids_final_2.csv', 'author_wikidata', author_query_template,)
get_supplement_from_wikidata('all_paintings', 'data/wikidata_paintings_ids_final_2.csv', 'item', paintings_query_template,)
get_supplement_from_wikidata('all_paintings', 'data/wikidata_paintings_ids_final_2.csv', 'item', paintings_query_template,)
# Out:
# Final file already exists. Skipping data retrieval.
# Resuming from batch 12521
# Processing 12873 batches with 643646 records...
# Completed batch 12523/12873 (97.3%)
# Completed batch 12522/12873 (97.3%)
# Completed batch 12524/12873 (97.3%)
# Completed batch 12525/12873 (97.3%)
# Completed batch 12526/12873 (97.3%)
# Completed batch 12527/12873 (97.3%)
# Completed batch 12528/12873 (97.3%)
# Completed batch 12530/12873 (97.3%)
# Completed batch 12529/12873 (97.3%)
# Completed batch 12531/12873 (97.3%)
# Checkpoint saved at batch 12531
# Completed batch 12534/12873 (97.4%)
# Completed batch 12533/12873 (97.4%)
# Completed batch 12532/12873 (97.4%)
# Completed batch 12535/12873 (97.4%)
# Completed batch 12536/12873 (97.4%)
# Completed batch 12537/12873 (97.4%)
# Completed batch 12538/12873 (97.4%)
# Completed batch 12539/12873 (97.4%)
# Completed batch 12540/12873 (97.4%)
# Completed batch 12541/12873 (97.4%)
# Checkpoint saved at batch 12541
# Completed batch 12544/12873 (97.4%)
# Completed batch 12543/12873 (97.4%)
# Completed batch 12542/12873 (97.4%)
# Completed batch 12545/12873 (97.5%)
# Completed batch 12546/12873 (97.5%)
# Completed batch 12548/12873 (97.5%)
# Completed batch 12549/12873 (97.5%)
# Completed batch 12547/12873 (97.5%)
# Completed batch 12550/12873 (97.5%)
# Completed batch 12551/12873 (97.5%)
# Checkpoint saved at batch 12551
# Completed batch 12553/12873 (97.5%)
# Completed batch 12552/12873 (97.5%)
# Completed batch 12554/12873 (97.5%)
# Completed batch 12556/12873 (97.5%)
# Completed batch 12555/12873 (97.5%)
# Completed batch 12559/12873 (97.6%)
# Completed batch 12557/12873 (97.5%)
# Completed batch 12558/12873 (97.6%)
# Completed batch 12560/12873 (97.6%)
# Completed batch 12561/12873 (97.6%)
# Checkpoint saved at batch 12561
# Completed batch 12564/12873 (97.6%)
# Completed batch 12562/12873 (97.6%)
# Completed batch 12563/12873 (97.6%)
# Completed batch 12565/12873 (97.6%)
# Completed batch 12566/12873 (97.6%)
# Completed batch 12569/12873 (97.6%)
# Completed batch 12568/12873 (97.6%)
# Completed batch 12567/12873 (97.6%)
# Completed batch 12570/12873 (97.6%)
# Completed batch 12571/12873 (97.7%)
# Checkpoint saved at batch 12571
# Completed batch 12573/12873 (97.7%)
# Completed batch 12574/12873 (97.7%)
# Completed batch 12572/12873 (97.7%)
# Completed batch 12575/12873 (97.7%)
# Completed batch 12576/12873 (97.7%)
# Completed batch 12579/12873 (97.7%)
# Completed batch 12577/12873 (97.7%)
# Completed batch 12578/12873 (97.7%)
# Completed batch 12581/12873 (97.7%)
# Completed batch 12580/12873 (97.7%)
# Checkpoint saved at batch 12580
# Completed batch 12584/12873 (97.8%)
# Completed batch 12583/12873 (97.7%)
# Completed batch 12582/12873 (97.7%)
# Completed batch 12585/12873 (97.8%)
# Completed batch 12586/12873 (97.8%)
# Completed batch 12588/12873 (97.8%)
# Completed batch 12589/12873 (97.8%)
# Completed batch 12587/12873 (97.8%)
# Completed batch 12591/12873 (97.8%)
# Completed batch 12590/12873 (97.8%)
# Checkpoint saved at batch 12590
# Completed batch 12593/12873 (97.8%)
# Completed batch 12592/12873 (97.8%)
# Completed batch 12594/12873 (97.8%)
# Completed batch 12596/12873 (97.8%)
# Completed batch 12595/12873 (97.8%)
# Completed batch 12598/12873 (97.9%)
# Completed batch 12597/12873 (97.9%)
# Completed batch 12599/12873 (97.9%)
# Completed batch 12600/12873 (97.9%)
# Completed batch 12601/12873 (97.9%)
# Checkpoint saved at batch 12601
# Completed batch 12604/12873 (97.9%)
# Completed batch 12602/12873 (97.9%)
# Completed batch 12603/12873 (97.9%)
# Completed batch 12606/12873 (97.9%)
# Completed batch 12605/12873 (97.9%)
# Completed batch 12607/12873 (97.9%)
# Completed batch 12608/12873 (97.9%)
# Completed batch 12609/12873 (97.9%)
# Completed batch 12610/12873 (98.0%)
# Completed batch 12611/12873 (98.0%)
# Checkpoint saved at batch 12611
# Completed batch 12613/12873 (98.0%)
# Completed batch 12614/12873 (98.0%)
# Completed batch 12615/12873 (98.0%)
# Completed batch 12616/12873 (98.0%)
# Completed batch 12612/12873 (98.0%)
# Completed batch 12618/12873 (98.0%)
# Completed batch 12619/12873 (98.0%)
# Completed batch 12617/12873 (98.0%)
# Completed batch 12621/12873 (98.0%)
# Completed batch 12620/12873 (98.0%)
# Checkpoint saved at batch 12620
# Completed batch 12624/12873 (98.1%)
# Completed batch 12623/12873 (98.1%)
# Completed batch 12622/12873 (98.1%)
# Completed batch 12626/12873 (98.1%)
# Completed batch 12625/12873 (98.1%)
# Completed batch 12627/12873 (98.1%)
# Completed batch 12628/12873 (98.1%)
# Completed batch 12629/12873 (98.1%)
# Completed batch 12630/12873 (98.1%)
# Completed batch 12631/12873 (98.1%)
# Checkpoint saved at batch 12631
# Completed batch 12633/12873 (98.1%)
# Completed batch 12632/12873 (98.1%)
# Completed batch 12634/12873 (98.1%)
# Completed batch 12636/12873 (98.2%)
# Completed batch 12635/12873 (98.2%)
# Completed batch 12639/12873 (98.2%)
# Completed batch 12638/12873 (98.2%)
# Completed batch 12637/12873 (98.2%)
# Completed batch 12641/12873 (98.2%)
# Completed batch 12640/12873 (98.2%)
# Checkpoint saved at batch 12640
# Completed batch 12643/12873 (98.2%)
# Completed batch 12642/12873 (98.2%)
# Completed batch 12644/12873 (98.2%)
# Completed batch 12645/12873 (98.2%)
# Completed batch 12646/12873 (98.2%)
# Completed batch 12647/12873 (98.2%)
# Completed batch 12649/12873 (98.3%)
# Completed batch 12648/12873 (98.3%)
# Completed batch 12650/12873 (98.3%)
# Completed batch 12651/12873 (98.3%)
# Checkpoint saved at batch 12651
# Completed batch 12653/12873 (98.3%)
# Completed batch 12652/12873 (98.3%)
# Completed batch 12654/12873 (98.3%)
# Completed batch 12655/12873 (98.3%)
# Completed batch 12656/12873 (98.3%)
# Completed batch 12657/12873 (98.3%)
# Completed batch 12658/12873 (98.3%)
# Completed batch 12659/12873 (98.3%)
# Completed batch 12660/12873 (98.3%)
# Completed batch 12661/12873 (98.4%)
# Checkpoint saved at batch 12661
# Completed batch 12662/12873 (98.4%)
# Completed batch 12664/12873 (98.4%)
# Completed batch 12663/12873 (98.4%)
# Completed batch 12665/12873 (98.4%)
# Completed batch 12666/12873 (98.4%)
# Completed batch 12668/12873 (98.4%)
# Completed batch 12667/12873 (98.4%)
# Completed batch 12669/12873 (98.4%)
# Completed batch 12670/12873 (98.4%)
# Completed batch 12671/12873 (98.4%)
# Checkpoint saved at batch 12671
# Completed batch 12673/12873 (98.4%)
# Completed batch 12672/12873 (98.4%)
# Completed batch 12675/12873 (98.5%)
# Completed batch 12674/12873 (98.5%)
# Completed batch 12676/12873 (98.5%)
# Completed batch 12678/12873 (98.5%)
# Completed batch 12677/12873 (98.5%)
# Completed batch 12679/12873 (98.5%)
# Completed batch 12681/12873 (98.5%)
# Completed batch 12680/12873 (98.5%)
# Checkpoint saved at batch 12680
# Completed batch 12682/12873 (98.5%)
# Completed batch 12683/12873 (98.5%)
# Completed batch 12684/12873 (98.5%)
# Completed batch 12685/12873 (98.5%)
# Completed batch 12686/12873 (98.5%)
# Completed batch 12687/12873 (98.6%)
# Completed batch 12688/12873 (98.6%)
# Completed batch 12689/12873 (98.6%)
# Completed batch 12691/12873 (98.6%)
# Completed batch 12692/12873 (98.6%)
# Checkpoint saved at batch 12692
# Completed batch 12693/12873 (98.6%)
# Completed batch 12690/12873 (98.6%)
# Completed batch 12695/12873 (98.6%)
# Completed batch 12694/12873 (98.6%)
# Completed batch 12698/12873 (98.6%)
# Completed batch 12697/12873 (98.6%)
# Completed batch 12699/12873 (98.6%)
# Completed batch 12696/12873 (98.6%)
# Completed batch 12700/12873 (98.7%)
# Completed batch 12701/12873 (98.7%)
# Checkpoint saved at batch 12701
# Completed batch 12703/12873 (98.7%)
# Completed batch 12702/12873 (98.7%)
# Completed batch 12704/12873 (98.7%)
# Completed batch 12705/12873 (98.7%)
# Completed batch 12706/12873 (98.7%)
# Completed batch 12709/12873 (98.7%)
# Completed batch 12708/12873 (98.7%)
# Completed batch 12710/12873 (98.7%)
# Completed batch 12711/12873 (98.7%)
# Completed batch 12707/12873 (98.7%)
# Checkpoint saved at batch 12707
# Completed batch 12714/12873 (98.8%)
# Completed batch 12712/12873 (98.7%)
# Completed batch 12713/12873 (98.8%)
# Completed batch 12715/12873 (98.8%)
# Completed batch 12716/12873 (98.8%)
# Completed batch 12718/12873 (98.8%)
# Completed batch 12719/12873 (98.8%)
# Completed batch 12717/12873 (98.8%)
# Completed batch 12720/12873 (98.8%)
# Completed batch 12721/12873 (98.8%)
# Checkpoint saved at batch 12721
# Completed batch 12722/12873 (98.8%)
# Completed batch 12723/12873 (98.8%)
# Completed batch 12724/12873 (98.8%)
# Completed batch 12726/12873 (98.9%)
# Completed batch 12725/12873 (98.9%)
# Completed batch 12727/12873 (98.9%)
# Completed batch 12728/12873 (98.9%)
# Completed batch 12729/12873 (98.9%)
# Completed batch 12730/12873 (98.9%)
# Completed batch 12731/12873 (98.9%)
# Checkpoint saved at batch 12731
# Completed batch 12734/12873 (98.9%)
# Completed batch 12732/12873 (98.9%)
# Completed batch 12733/12873 (98.9%)
# Completed batch 12735/12873 (98.9%)
# Completed batch 12736/12873 (98.9%)
# Completed batch 12737/12873 (98.9%)
# Completed batch 12738/12873 (99.0%)
# Completed batch 12739/12873 (99.0%)
# Completed batch 12740/12873 (99.0%)
# Completed batch 12741/12873 (99.0%)
# Checkpoint saved at batch 12741
# Completed batch 12744/12873 (99.0%)
# Completed batch 12743/12873 (99.0%)
# Completed batch 12742/12873 (99.0%)
# Completed batch 12746/12873 (99.0%)
# Completed batch 12745/12873 (99.0%)
# Completed batch 12748/12873 (99.0%)
# Completed batch 12749/12873 (99.0%)
# Completed batch 12747/12873 (99.0%)
# Completed batch 12751/12873 (99.1%)
# Completed batch 12750/12873 (99.0%)
# Checkpoint saved at batch 12750
# Completed batch 12754/12873 (99.1%)
# Completed batch 12753/12873 (99.1%)
# Completed batch 12752/12873 (99.1%)
# Completed batch 12755/12873 (99.1%)
# Completed batch 12756/12873 (99.1%)
# Completed batch 12758/12873 (99.1%)
# Completed batch 12759/12873 (99.1%)
# Completed batch 12757/12873 (99.1%)
# Completed batch 12761/12873 (99.1%)
# Completed batch 12760/12873 (99.1%)
# Checkpoint saved at batch 12760
# Completed batch 12762/12873 (99.1%)
# Completed batch 12763/12873 (99.1%)
# Completed batch 12764/12873 (99.2%)
# Completed batch 12765/12873 (99.2%)
# Completed batch 12766/12873 (99.2%)
# Completed batch 12767/12873 (99.2%)
# Completed batch 12768/12873 (99.2%)
# Completed batch 12769/12873 (99.2%)
# Completed batch 12771/12873 (99.2%)
# Completed batch 12770/12873 (99.2%)
# Checkpoint saved at batch 12770
# Completed batch 12774/12873 (99.2%)
# Completed batch 12772/12873 (99.2%)
# Completed batch 12773/12873 (99.2%)
# Completed batch 12775/12873 (99.2%)
# Completed batch 12776/12873 (99.2%)
# Completed batch 12777/12873 (99.3%)
# Completed batch 12778/12873 (99.3%)
# Completed batch 12779/12873 (99.3%)
# Completed batch 12781/12873 (99.3%)
# Completed batch 12780/12873 (99.3%)
# Checkpoint saved at batch 12780
# Completed batch 12784/12873 (99.3%)
# Completed batch 12783/12873 (99.3%)
# Completed batch 12786/12873 (99.3%)
# Completed batch 12785/12873 (99.3%)
# Completed batch 12782/12873 (99.3%)
# Completed batch 12788/12873 (99.3%)
# Completed batch 12787/12873 (99.3%)
# Completed batch 12789/12873 (99.3%)
# Completed batch 12790/12873 (99.4%)
# Completed batch 12791/12873 (99.4%)
# Checkpoint saved at batch 12791
# Completed batch 12792/12873 (99.4%)
# Completed batch 12793/12873 (99.4%)
# Completed batch 12794/12873 (99.4%)
# Completed batch 12796/12873 (99.4%)
# Completed batch 12795/12873 (99.4%)
# Completed batch 12799/12873 (99.4%)
# Completed batch 12797/12873 (99.4%)
# Completed batch 12798/12873 (99.4%)
# Completed batch 12800/12873 (99.4%)
# Completed batch 12801/12873 (99.4%)
# Checkpoint saved at batch 12801
# Completed batch 12803/12873 (99.5%)
# Completed batch 12804/12873 (99.5%)
# Completed batch 12802/12873 (99.4%)
# Completed batch 12806/12873 (99.5%)
# Completed batch 12805/12873 (99.5%)
# Completed batch 12807/12873 (99.5%)
# Completed batch 12809/12873 (99.5%)
# Completed batch 12808/12873 (99.5%)
# Completed batch 12810/12873 (99.5%)
# Completed batch 12811/12873 (99.5%)
# Checkpoint saved at batch 12811
# Completed batch 12813/12873 (99.5%)
# Completed batch 12812/12873 (99.5%)
# Completed batch 12814/12873 (99.5%)
# Completed batch 12816/12873 (99.6%)
# Completed batch 12815/12873 (99.5%)
# Completed batch 12818/12873 (99.6%)
# Completed batch 12820/12873 (99.6%)
# Completed batch 12819/12873 (99.6%)
# Completed batch 12817/12873 (99.6%)
# Completed batch 12821/12873 (99.6%)
# Checkpoint saved at batch 12821
# Completed batch 12822/12873 (99.6%)
# Completed batch 12823/12873 (99.6%)
# Completed batch 12825/12873 (99.6%)
# Completed batch 12824/12873 (99.6%)
# Completed batch 12826/12873 (99.6%)
# Completed batch 12827/12873 (99.6%)
# Completed batch 12829/12873 (99.7%)
# Completed batch 12828/12873 (99.7%)
# Completed batch 12831/12873 (99.7%)
# Completed batch 12830/12873 (99.7%)
# Checkpoint saved at batch 12830
# Completed batch 12833/12873 (99.7%)
# Completed batch 12834/12873 (99.7%)
# Completed batch 12832/12873 (99.7%)
# Completed batch 12835/12873 (99.7%)
# Completed batch 12836/12873 (99.7%)
# Completed batch 12837/12873 (99.7%)
# Completed batch 12839/12873 (99.7%)
# Completed batch 12838/12873 (99.7%)
# Completed batch 12841/12873 (99.8%)
# Completed batch 12840/12873 (99.7%)
# Checkpoint saved at batch 12840
# Completed batch 12842/12873 (99.8%)
# Completed batch 12844/12873 (99.8%)
# Completed batch 12843/12873 (99.8%)
# Completed batch 12846/12873 (99.8%)
# Completed batch 12845/12873 (99.8%)
# Completed batch 12848/12873 (99.8%)
# Completed batch 12849/12873 (99.8%)
# Completed batch 12847/12873 (99.8%)
# Completed batch 12850/12873 (99.8%)
# Completed batch 12851/12873 (99.8%)
# Checkpoint saved at batch 12851
# Completed batch 12852/12873 (99.8%)
# Completed batch 12853/12873 (99.8%)
# Completed batch 12854/12873 (99.9%)
# Completed batch 12855/12873 (99.9%)
# Completed batch 12856/12873 (99.9%)
# Completed batch 12858/12873 (99.9%)
# Completed batch 12857/12873 (99.9%)
# Completed batch 12859/12873 (99.9%)
# Completed batch 12861/12873 (99.9%)
# Completed batch 12860/12873 (99.9%)
# Checkpoint saved at batch 12860
# Completed batch 12862/12873 (99.9%)
# Completed batch 12864/12873 (99.9%)
# Completed batch 12863/12873 (99.9%)
# Completed batch 12866/12873 (99.9%)
# Completed batch 12865/12873 (99.9%)
# Completed batch 12869/12873 (100.0%)
# Completed batch 12868/12873 (100.0%)
# Completed batch 12867/12873 (100.0%)
# Completed batch 12870/12873 (100.0%)
# Completed batch 12871/12873 (100.0%)
# Checkpoint saved at batch 12871
# Completed batch 12873/12873 (100.0%)
# Completed batch 12872/12873 (100.0%)
# Processing complete. Preparing final dataset...
# Data saved to wikidata_all_paintings.csv
