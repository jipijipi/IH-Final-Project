# %% [markdown]
# # Food in Art

# %%
import pandas as pd
import os
import time
import concurrent.futures
from typing import List, Dict
import requests
from ratelimit import limits, sleep_and_retry

# %%
# Initialize global session for connection pooling
session = requests.Session()
session.headers.update({
    'User-Agent': 'ArtDataBot/1.0 (jipijipijipi@gmail.com) Python/requests',
    'Accept': 'application/json'
})

@sleep_and_retry
@limits(calls=5, period=1)  # Limit to 5 calls per second
def run_sparql_query(query: str, endpoint_url: str) -> Dict:
    """Execute SPARQL query with rate limiting"""
    response = session.get(
        endpoint_url,
        params={'query': query, 'format': 'json'},
        timeout=30
    )
    response.raise_for_status()
    return response.json()

def process_batch(batch_qids: List[str], endpoint_url: str, max_retries: int = 5) -> pd.DataFrame:
    """Process a single batch of author QIDs"""
    qid_list_str = ' '.join(f'wd:{qid}' for qid in batch_qids)
    
    # Optimized SPARQL query
    batch_query = f"""
    SELECT ?author ?author_name ?country ?country_label ?gender ?gender_label 
           # ?date_of_birth ?place_of_birth ?place_of_birth_label 
           # ?place_of_birth_country ?place_of_birth_country_label 
    WHERE {{
        VALUES ?author {{ {qid_list_str} }}
        
        OPTIONAL {{
            # ?author rdfs:label ?author_name;
                    wdt:P27 ?country;
                    wdt:P21 ?gender;
                    wdt:P569 ?date_of_birth;
                    wdt:P19 ?place_of_birth.
            
            # ?country rdfs:label ?country_label.
            # ?gender rdfs:label ?gender_label.
            # ?place_of_birth rdfs:label ?place_of_birth_label.
            # ?place_of_birth wdt:P17 ?place_of_birth_country.
            # ?place_of_birth_country rdfs:label ?place_of_birth_country_label.
            
            FILTER(LANG(?author_name) = "en")
            FILTER(LANG(?country_label) = "en")
            FILTER(LANG(?gender_label) = "en")
            FILTER(LANG(?place_of_birth_label) = "en")
            FILTER(LANG(?place_of_birth_country_label) = "en")
        }}
    }}"""

    for retry in range(max_retries):
        try:
            results = run_sparql_query(batch_query, endpoint_url)
            bindings = results['results']['bindings']
            
            if not bindings:
                return pd.DataFrame()

            data = [{
                'author_wikidata': b['author']['value'],
                'name': b.get('author_name', {}).get('value'),
                'country': b.get('country_label', {}).get('value'),
                'birth_country': b.get('place_of_birth_country_label', {}).get('value'),
                'birth_place': b.get('place_of_birth_label', {}).get('value'),
                'gender': b.get('gender_label', {}).get('value'),
                'date_of_birth': b.get('date_of_birth', {}).get('value')
            } for b in bindings]
            
            return pd.DataFrame(data)
            
        except Exception as e:
            if retry == max_retries - 1:
                print(f"Max retries exceeded: {e}")
                return pd.DataFrame()
            time.sleep(2 ** retry)  # Exponential backoff
    
    return pd.DataFrame()

def chunk_list(lst: List, chunk_size: int) -> List[List]:
    """Split a list into chunks of specified size"""
    return [lst[i:i + chunk_size] for i in range(0, len(lst), chunk_size)]

def get_supplement_from_wikidata():
    # Configuration
    endpoint_url = "https://query.wikidata.org/sparql"
    batch_size = 50
    max_workers = 3  # Adjust based on your needs and API limits
    checkpoint_frequency = 10  # Save checkpoint every N batches

    if os.path.exists('data/wikidata_painters.csv'):
        print("Final file already exists. Skipping data retrieval.")
        return

    # Create checkpoint directory if it doesn't exist
    os.makedirs('data/checkpoints', exist_ok=True)

    # Load checkpoint if exists
    checkpoint_file = 'data/checkpoints/authors_checkpoint.csv'
    batch_index_file = 'data/checkpoints/authors_batch_index_checkpoint.txt'
    
    if os.path.exists(checkpoint_file) and os.path.exists(batch_index_file):
        detailed_data = pd.read_csv(checkpoint_file)
        with open(batch_index_file, 'r') as f:
            start_batch = int(f.read())
        print(f"Resuming from batch {start_batch}")
    else:
        detailed_data = pd.DataFrame()
        start_batch = 0

    # Read and prepare author data
    basic_data = pd.read_csv('data/wikidata_paintings_ids_final_2.csv')
    authors = basic_data['author_wikidata'].drop_duplicates().reset_index(drop=True)
    
    # Convert item URIs to Q-IDs and create batches
    author_qids = [uri.split('/')[-1] for uri in authors['author_wikidata'].tolist()]
    print(author_qids)
    batches = chunk_list(author_qids, batch_size)

    print(f"Processing {len(batches)} batches with {len(author_qids)} authors...")

    # Process batches with ThreadPoolExecutor
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {
            executor.submit(process_batch, batch, endpoint_url): batch_idx 
            for batch_idx, batch in enumerate(batches[start_batch:], start=start_batch)
        }
        
        completed_batches = 0
        for future in concurrent.futures.as_completed(futures):
            batch_idx = futures[future]
            try:
                batch_df = future.result()
                if not batch_df.empty:
                    detailed_data = pd.concat([detailed_data, batch_df], ignore_index=True)
                
                completed_batches += 1
                print(f"Completed batch {batch_idx + 1}/{len(batches)} "
                      f"({(batch_idx + 1)/len(batches)*100:.1f}%)")

                # Save checkpoint periodically
                if completed_batches % checkpoint_frequency == 0:
                    detailed_data.to_csv(checkpoint_file, index=False)
                    with open(batch_index_file, 'w') as f:
                        f.write(str(batch_idx + 1))
                    print(f"Checkpoint saved at batch {batch_idx + 1}")

            except Exception as e:
                print(f"Error processing batch {batch_idx}: {e}")

    # Final processing
    print("Processing complete. Preparing final dataset...")
    detailed_data.drop_duplicates(subset=['author_wikidata'], inplace=True)
    final_data = pd.merge(authors, detailed_data, on='author_wikidata', how='left')
    
    # Save final results
    final_data.to_csv('data/wikidata_painters.csv', index=False)
    print("Data saved to wikidata_painters.csv")

    # Clean up checkpoints
    if os.path.exists(checkpoint_file):
        os.remove(checkpoint_file)
    if os.path.exists(batch_index_file):
        os.remove(batch_index_file)

if __name__ == "__main__":
    get_supplement_from_wikidata()
# Out:
# Processing 2673 batches with 133646 authors...
# Max retries exceeded: 400 Client Error: Bad Request for url: https://query.wikidata.org/sparql?query=%0A++++SELECT+%3Fauthor+%3Fauthor_name+%3Fcountry+%3Fcountry_label+%3Fgender+%3Fgender_label+%0A+++++++++++%3Fdate_of_birth+%3Fplace_of_birth+%3Fplace_of_birth_label+%0A+++++++++++%3Fplace_of_birth_country+%3Fplace_of_birth_country_label+%0A++++WHERE+%7B%0A++++++++VALUES+%3Fauthor+%7B+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2F.well-known%2Fgenid%2F195f8d395b47639d97d86068e10fa9d9+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ156386+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ704600+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ128538+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ5603+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ366212+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ1393857+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ130777+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ152797+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ203643+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ150679+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ725681+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ5577+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ35548+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ80442+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ301+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ215590+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ538713+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2F.well-known%2Fgenid%2Fbf885fad93d1e0941c4b61652ee6e3ff+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ186748+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ17169+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ326434+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ27028228+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ348024+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ155626+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ15792+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ155575+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ597063+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ153746+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ191748+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ205863+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ
el+%3Fplace_of_birth_label.%0A++++++++++++%3Fplace_of_birth+wdt%3AP17+%3Fplace_of_birth_country.%0A++++++++++++%3Fplace_of_birth_country+rdfs%3Alabel+%3Fplace_of_birth_country_label.%0A++++++++++++%0A++++++++++++FILTER%28LANG%28%3Fauthor_name%29+%3D+%22en%22%29%0A++++++++++++FILTER%28LANG%28%3Fcountry_label%29+%3D+%22en%22%29%0A++++++++++++FILTER%28LANG%28%3Fgender_label%29+%3D+%2 ...
# Completed batch 1/2673 (0.0%)
# Max retries exceeded: 400 Client Error: Bad Request for url: https://query.wikidata.org/sparql?query=%0A++++SELECT+%3Fauthor+%3Fauthor_name+%3Fcountry+%3Fcountry_label+%3Fgender+%3Fgender_label+%0A+++++++++++%3Fdate_of_birth+%3Fplace_of_birth+%3Fplace_of_birth_label+%0A+++++++++++%3Fplace_of_birth_country+%3Fplace_of_birth_country_label+%0A++++WHERE+%7B%0A++++++++VALUES+%3Fauthor+%7B+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ184212+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ159758+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ637420+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ334262+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ548914+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ240526+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ134741+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ7824+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2F.well-known%2Fgenid%2Ff0b32d6de88af35fbb643672b7f73247+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ205148+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ203828+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ189117+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ290812+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ704984+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ983275+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ207298+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ2060254+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ5811+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ106851+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2F.well-known%2Fgenid%2F24528379a87862483f9a5d400b289830+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ450490+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ41554+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ203371+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ46373+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ67863900+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ8457+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ702525+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ271884+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2F.well-known%2Fgenid%2Fd44dc09191417527b9f61445fb891940+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ365544+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ26408+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ933502+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ918605+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ297838+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ155376+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2F.well-known%2Fgenid%2Fce30aa89979c3eb2d07dafe03636a213+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ927350+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ7814+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ2327761+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ726564+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ23380+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ379300+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ63531+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ164961+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ187310+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ64881+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ214905+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ2977133+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ120993+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ109061+%7D%0A++++++++%0A++++++++OPTIONAL+%7B%0A++++++++++++%3Fauthor+rdfs%3Alabel+%3Fauthor_name%3B%0A++++++++++++++++++++wdt%3AP27+%3Fcountry%3B%0A++++++++++++++++++++wdt%3AP21+%3Fgender%3B%0A++++++++++++++++++++wdt%3AP569+%3Fdate_of_birth%3B%0A++++++++++++++++++++wdt%3AP19+%3Fplace_of_birth.%0A++++++++++++%0A++++++++++++%3Fcountry+rdfs%3Alabel+%3Fcountry_label.%0A++++++++++++%3Fgender+rdfs%3Alabel+%3Fgender_label.%0A++++++++++++%3Fplace_of_birth+rdfs%3Alabel+%3Fplace_of_birth_label.%0A++++++++++++%3Fplace_of_birth+wdt%3AP17+%3Fplace_of_birth_country.%0A++++++++++++%3Fplace_of_birth_country+rdfs%3Alabel+%3Fplace_of_birth_country_label.%0A++++++++++++%0A++++++++++++FILTER%28LANG%28%3Fauthor_name%29+%3D+%22en%22%29%0A++++++++++++FILTER%28LANG%28%3Fcountry_label%29+%3D ...
# Completed batch 3/2673 (0.1%)
# Max retries exceeded: 400 Client Error: Bad Request for url: https://query.wikidata.org/sparql?query=%0A++++SELECT+%3Fauthor+%3Fauthor_name+%3Fcountry+%3Fcountry_label+%3Fgender+%3Fgender_label+%0A+++++++++++%3Fdate_of_birth+%3Fplace_of_birth+%3Fplace_of_birth_label+%0A+++++++++++%3Fplace_of_birth_country+%3Fplace_of_birth_country_label+%0A++++WHERE+%7B%0A++++++++VALUES+%3Fauthor+%7B+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ
wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ1393742+%7D%0A++++++++%0A++++++++OPTIONAL+%7B%0A++++++++++++%3Fauthor+rdfs%3Alabel+%3Fauthor_name%3B%0A++++++++++++++++++++wdt%3AP27+%3Fcountry%3B%0A++++++++++++++++++++wdt%3AP21+%3Fgender%3B%0A++++++++++++++++++++wdt%3AP569+%3Fdate_of_birth%3B%0A++++++++++++++++++++wdt%3AP19+%3Fplace_of_birth.%0A++++++++++++%0A++++++++++++%3Fcountry+rdfs%3Alabel+%3Fcountry_label.%0A++++++++++++%3Fgender+rdfs%3Alabel+%3Fgender_label.%0A++++++++++++%3Fplace_of_birth+rdfs%3Alabel+%3Fplace_of_birth_label.%0A++++++++++++%3Fplace_of_birth+wdt%3AP17+%3Fplace_of_birth_country.%0A++++++++++++%3Fplace_of_birth_country+rdfs%3Alabel+%3Fplace_of_birth_country_label.%0A++++++++++++%0A++++++++++++FILTER%28LANG%28%3Fauthor_name%29+%3D+%22en%22%29%0A++++++++++++FILTER%28LANG%28%3Fcountry_label%29+%3D+%22en%22%29%0A++++++++++++FILTER%28LANG%28%3Fgender_la ...
# Max retries exceeded: 400 Client Error: Bad Request for url: https://query.wikidata.org/sparql?query=%0A++++SELECT+%3Fauthor+%3Fauthor_name+%3Fcountry+%3Fcountry_label+%3Fgender+%3Fgender_label+%0A+++++++++++%3Fdate_of_birth+%3Fplace_of_birth+%3Fplace_of_birth_label+%0A+++++++++++%3Fplace_of_birth_country+%3Fplace_of_birth_country_label+%0A++++WHERE+%7B%0A++++++++VALUES+%3Fauthor+%7B+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ551896+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ378555+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2F.well-known%2Fgenid%2Fefa80ce2ac33d6713c49a1184ce2b9f2+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ449519+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ1357729+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ5592+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ355213+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ211763+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ82445+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ313498+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ319843+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2F.well-known%2Fgenid%2F384fb97475201a1ee5afae6df3fee056+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ356777+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ221043+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ3745137+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2F.well-known%2Fgenid%2F6995e6fa2c16366a265a650baaf7ea27+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ3396084+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ538350+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ93284+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ236038+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ982538+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ223725+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ173223+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ767225+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ326548+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ7770+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ5581+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ41513+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ3518238+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ537712+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ690593+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ539474+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ333323+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ158840+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ371171+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ156622+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ34013+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ353628+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ355563+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ164712+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ732468+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ523603+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ434006+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ41406+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ647934+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ460198+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ45205+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ153793+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ3262017+wd%3Ahttp%3A%2F%2Fwww.wikidata.org%2Fentity%2FQ312616+%7D%0A++++++++%0A++++++++OPTIONAL+%7B%0A++++++++++++%3Fauthor+rdfs%3Alabel+%3Fauthor_name%3B%0A++++++++++++++++++++wdt%3AP27+%3Fcountry%3B%0A++++++++++++++++++++wdt%3AP21+%3Fgender%3B%0A++++++++++++++++++++wdt%3AP569+%3Fdate_of_birth%3B%0A++++++++++++++++++++wdt%3AP19+%3Fplace_of_birth.%0A++++++++++++%0A++++++++++++%3Fcountry+rdfs%3Alabel+%3Fcountry_label.%0A++++++++++++%3Fgender+rdfs%3Alabel+%3Fgender_label.%0A++++++++++++%3Fplace_of_birth+rdfs%3Alabel+%3Fplace_of_birth_label.%0A++++++++++++%3Fplace_of_birth+wdt%3AP17+%3Fplace_of_birth_country.%0A++++++++++++%3Fplace_of_birth_country+rdfs%3Alabel+%3Fplace_of_birth_country_label.%0A++++++++++++%0A++++++++++++FILTER%28LANG%28%3Fauthor_name%29+%3D+%22en%22%29%0A++++++++++++FILTER%28LANG%28%3Fcountry_label%29+%3D+%22en%22%29%0A++++++++++++FILTER%28 ...
